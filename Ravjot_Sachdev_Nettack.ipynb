# %% [markdown]
# # Ravjot Sachdev
# ## CIS 700 Midterm
# ## Topic 2: Evading Malware Adversarial Attacks for Graph Data
# ## May 23, 2021

# %% [markdown]
# The selected topic concerns adversarial attacks on graph data. One such model is the Nettack model, which introduces perturbations into the nodes and edges of a graph to cause misclassifications. The selected code can be found at https://github.com/danielzuegner/nettack.

# %%
# %cd nettack
# Out:
# C:\Users\ravsa\Downloads\SU\Spring 2021\Midterm_Spring_2021\nettack

# %% [markdown]
# First, we install the necessary packages.

# %%
# !pip install numpy==1.16.1
# !python setup.py install
# Out:
# ...
#   Using cached numpy-1.16.1-cp37-cp37m-win_amd64.whl (11.9 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.20.3
#     Uninstalling numpy-1.20.3:
#       Successfully uninstalled numpy-1.20.3
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'c:\\users\\ravsa\\anaconda3\\envs\\cis-700_midterm\\lib\\site-packages\\~.mpy\\.libs\\libopenblas.GK7GX5KEQ4F6UYO3P26ULGBQYHGQO7J4.gfortran-win_amd64.dll'
# Consider using the `--user` option or check the permissions.
# running install
# running bdist_egg
# running egg_info
# writing nettack.egg-info\PKG-INFO
# writing dependency_links to nettack.egg-info\dependency_links.txt
# writing requirements to nettack.egg-info\requires.txt
# writing top-level names to nettack.egg-info\top_level.txt
# reading manifest file 'nettack.egg-info\SOURCES.txt'
# writing manifest file 'nettack.egg-info\SOURCES.txt'
# installing library code to build\bdist.win-amd64\egg
# running install_lib
# ...

# %% [markdown]
# The provided demo notebook can be run to demonstrate the Nettack model.

# %%
# %run ./demo.ipynb
# Out:
# WARNING:tensorflow:From C:\Users\ravsa\Downloads\SU\Spring 2021\Midterm_Spring_2021\nettack\nettack\GCN.py:6: The name tf.sparse_tensor_dense_matmul is deprecated. Please use tf.sparse.sparse_dense_matmul instead.
#
# Selecting 1 largest connected components
# WARNING:tensorflow:From C:\Users\ravsa\Downloads\SU\Spring 2021\Midterm_Spring_2021\nettack\nettack\GCN.py:60: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From C:\Users\ravsa\Downloads\SU\Spring 2021\Midterm_Spring_2021\nettack\nettack\GCN.py:74: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\ravsa\Downloads\SU\Spring 2021\Midterm_Spring_2021\nettack\nettack\GCN.py:78: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# ...

# %% [markdown]
# ## Results
# The graph above demonstrates the effectiveness of the Nettack model in attack a node classification algorithm by modifying graph data. On the left side, we see that the classifier successfully classified a majority of the nodes as Class 1, the correct class. After introducing 12 perturbations, or changes to nodes or edges, within the graph, the classifier actually failed to classify many samples. Class 4 was the more popular choice after the adversarial training. Nettack was one of the more effective attacks of the ones selected in the literature review, and at the very least, this demo shows it is quite effective in this instance.
